# %%
import pandas as pd
import openpyxl
import os

# %%
path = "../src/data/tortilleria.xlsx"

df = pd.read_excel(path)

df
# Out:
# Empty DataFrame
# Columns: [Codigo de Barras, Nombre, Precio, Cantidad, Categoria]
# Index: []
